# %% [markdown]
# # Statistical Methods in Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lesson you'll get some hands on experience using some of the key summary statistics methods in Pandas.

# %% [markdown]
# ## Objectives:
# You will be able to:
#
# * Understand and use the df.describe() and df.info() summary statistics methods
# * Use built-in Pandas methods for calculating summary statistics (.mean(), .std(), .count(), .sum(), .mean(), .median(), .std(), .var() and .quantile())
# * Apply a function to every element in a Series or DataFrame using s.apply() and df.applymap()
#
#
# ## Getting Started
#
# For this lab, we'll be working with a dataset containing information on various lego datasets.  You will find this dataset in the file `lego_sets.csv`.
#
# In the cell below:
#
# * Import pandas and set the standard alias of `pd`
# * Load in the `lego_sets.csv`dataset using the `read_csv()` function
# * Display the head of the DataFrame to get a feel for what we'll be working with

# %%
import pandas as pd

# %%
df = pd.read_csv('lego_sets.csv')
df.head()
# Out:
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0  6-12       29.99          2.0        277.0               4.0
# 1  6-12       19.99          2.0        168.0               4.0
# 2  6-12       12.99         11.0         74.0               4.3
# 3   12+       99.99         23.0       1032.0               3.6
# 4   12+       79.99         14.0        744.0               3.2
#
#                                            prod_desc  prod_id  \
# 0  Catapult into action and take back the eggs fr...  75823.0
# 1  Launch a flying attack and rescue the eggs fro...  75822.0
# 2  Chase the piggy with lightning-fast Chuck and ...  75821.0
# 3  Explore the architecture of the United States ...  21030.0
# 4  Recreate the Solomon R. Guggenheim Museum® wit...  21035.0
#
#                                       prod_long_desc review_difficulty  \
# 0  Use the staircase catapult to launch Red into ...           Average
# 1  Pilot Pig has taken off from Bird Island with ...              Easy
# 2  Pitch speedy bird Chuck against the Piggy Car....              Easy
# 3  Discover the architectural secrets of the icon...           Average
# 4  Discover the architectural secrets of Frank Ll...       Challenging
#
#                          set_name  star_rating    theme_name  val_star_rating  \
# 0           Bird Island Egg Heist          4.5  Angry Birds™              4.0
# 1              Piggy Plane Attack          5.0  Angry Birds™              4.0
# 2                Piggy Car Escape          4.3  Angry Birds™              4.1
# 3  United States Capitol Building          4.6  Architecture              4.3
# 4   Solomon R. Guggenheim Museum®          4.6  Architecture              4.1
#
#   country
# 0      US
# 1      US
# 2      US
# 3      US
# 4      US

# %% [markdown]
# ## Getting DataFrame-Level Statistics
#
# We'll begin by getting some overall summary statistics on the dataset.  There are two ways we'll get this information-- `.info()` and `.describe()`.
#
# ### Using `.info()`
#
# The `.info()` method provides us metadata on the DataFrame itself.  This allows to answer questions such as:
#
# * What data type does each column contain?
# * How many rows are in my dataset?
# * How many total non-missing values does each column contain?
# * How much memory does the DataFrame take up?
#
# In the cell below, call our DataFrame's `.info()` method.

# %%
df.info()
df[df.isnull().any(1)]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 14 columns):
# ages                 12261 non-null object
# list_price           12261 non-null float64
# num_reviews          10641 non-null float64
# piece_count          12261 non-null float64
# play_star_rating     10486 non-null float64
# prod_desc            11884 non-null object
# prod_id              12261 non-null float64
# prod_long_desc       12261 non-null object
# review_difficulty    10206 non-null object
# set_name             12261 non-null object
# star_rating          10641 non-null float64
# theme_name           12258 non-null object
# val_star_rating      10466 non-null float64
# country              12261 non-null object
# dtypes: float64(7), object(7)
# memory usage: 1.3+ MB
#         ages  list_price  num_reviews  piece_count  play_star_rating  \
# 22       10+      9.9900          1.0        136.0               NaN
# 32       10+     19.9900          NaN        209.0               NaN
# 48      5-12     49.9900          NaN        387.0               NaN
# 55      7-12     99.9900          1.0        883.0               5.0
# 69      5-12     39.9900          NaN        297.0               NaN
# 84       4-7     19.9900          NaN        115.0               NaN
# 92       4-7      9.9900          NaN         73.0               NaN
# 94      5-12      9.9900          2.0         88.0               NaN
# 103     5-12     49.9900          2.0        403.0               4.5
# 108     5-12     29.9900          NaN        195.0               NaN
# 153     6-12      9.9900          NaN        109.0               NaN
# 162     7-12     19.9900          NaN        246.0               NaN
# 163     6-12      9.9900          2.0        124.0               4.0
# 192     7-14     19.9900          2.0        198.0               4.0
# 199      10+     19.9900          NaN        209.0               NaN
# 205     9-12     99.9900          NaN       1078.0               NaN
# 208     7-12     59.9900          NaN        432.0               NaN
# 227     9-12     99.9900          NaN       1078.0               NaN
# 228     7-12     59.9900          NaN        432.0               NaN
# 231     7-14     14.9900          NaN         56.0               NaN
# 234     7-14     24.9900          NaN         93.0               NaN
# 261     5-12     19.9900          NaN        125.0               NaN
# 267      4-7      9.9900          1.0         75.0               5.0
# 277     5-12      9.9900          NaN         75.0               NaN
# 278     5-12      5.9900          NaN         61.0               NaN
# 279      2-5     29.9900          NaN         22.0               NaN
# 280      2-5     19.9900          1.0         24.0               NaN
# 284      2-5     59.9900          NaN        104.0               NaN
# 285      2-5     59.9900          NaN         98.0               NaN
# 287      2-5     49.9900          NaN         71.0               NaN
# ...      ...         ...          ...          ...               ...
# 12048  10-21    243.9878          1.0          1.0               5.0
# 12049  10-21     42.6878          NaN          1.0               NaN
# 12050    10+     42.6878          4.0          1.0               3.0
# 12051  10-21     42.6878          1.0          1.0               5.0
# 12052  10-21     42.6878          NaN          1.0               NaN
# 12053    10+     42.6878          3.0          1.0               5.0
# 12054     8+     36.5878          2.0          1.0               5.0
# 12055  10-21     36.5878          2.0          1.0               5.0
# 12056  10-21     30.4878          1.0          1.0               5.0
# 12057  10-21     24.3878          NaN          1.0               NaN
# 12058  10-21     18.2878          NaN          7.0               NaN
# 12065     8+     54.8878          NaN        278.0               NaN
# 12071   6-14     18.2878          NaN         84.0               NaN
# 12078   8-14     69.5278          NaN        569.0               NaN
# 12080   8-14     36.5878          NaN        369.0               NaN
# 12082   7-14     24.3878          NaN        217.0               NaN
# 12096   8-14     54.8878          NaN        530.0               NaN
# 12106    4-7     24.3878          NaN        131.0               NaN
# 12108   6-14     12.1878          NaN         61.0               NaN
# 12111   6-14     12.1878          NaN         69.0               NaN
# 12113   6-14     12.1878          NaN         69.0               NaN
# 12115     6+    853.9878          7.0       2631.0               4.7
# 12116     6+    683.1878          8.0       2455.0               3.7
# 12117     6+    439.1878          2.0       4900.0               5.0
# 12118     6+     32.9278         10.0        219.0               3.9
# 12136   8-14     36.5878          NaN        104.0               NaN
# 12137   8-14     36.5878          NaN        101.0               NaN
# 12196    14+    243.9878          NaN       1967.0               NaN
# 12214   7-14     24.3878          1.0        135.0               5.0
# 12235   7-14     30.4878          2.0        198.0               4.0
#
#                                                prod_desc    prod_id  \
# 22     Master the skills of a green-skinned assassin ...    41607.0
# 32     Join the Justice League™ with LEGO® BrickHeadz...    41610.0
# 48     Keep the crooks from escaping with the gold bars!    60175.0
# 55     Head to the LEGO® City mine and dig up some gold!    60188.0
# 69     Race after the crook and avoid the mountain ro...    60172.0
# 84            Chase down the crook and recover the loot!    10751.0
# 92                     Grab your shovel and get to work!    10750.0
# 94        Arrest the crooks and recover the hidden loot!    60171.0
# 103       Stop the crooks from stealing their car again!    60143.0
# 108        Rescue the sailor off the rocks just in time!    60168.0
# 153    Enter the racing world with the 3-in-1 Extreme...    31072.0
# 162                Take the 3-in-1 Airshow Aces to town!    31060.0
# 163                                                  NaN    31043.0
# 192    Bring down Captain Boomerang™ with Batman’s Ba...    70918.0
# 199    Join the Justice League™ with LEGO® BrickHeadz...    41610.0
# 205         Rescue The Flash™ from Eclipso’s evil plans!    41239.0
# 208    Stop Lena Luthor™ from making evil little Kryp...    41238.0
# 227         Rescue The Flash™ from Eclipso’s evil plans!    41239.0
# 228    Stop Lena Luthor™ from making evil little Kryp...    41238.0
# 231    Get ready to save the day in the LEGO® DIMENSI...    71287.0
# 234    Sugar, spice and everything nice! Bring Townsv...    71346.0
# 261           Visit Arendelle Market with Elsa and Olaf!    41155.0
# 267    Pull in to Disney•Pixar’s Guido & Luigi’s Pit ...    10732.0
# 277              Win the show jumping prize with Petite!    41144.0
# 278                   Make a cake for Berry’s tea party!    41143.0
# 279    Help Owen Grady get the escaped T. rex under c...    10880.0
# 280    See the baby dinosaurs at the Jurassic World G...    10879.0
# 284    Enjoy a visit to the adventure farm and feed t...    10869.0
# 285    Explore the Town Square for endless fun and pl...    10836.0
# 287    Develop creativity and fine motor skills with ...    10864.0
# ...                                                  ...        ...
# 12048                                                NaN    45500.0
# 12049                                                NaN    45505.0
# 12050                                                NaN    45504.0
# 12051                                                NaN    45506.0
# 12052                                                NaN    45509.0
# 12053                                                NaN    45508.0
# 12054                                                NaN    45517.0
# 12055                                                NaN    45502.0
# 12056                                                NaN    45503.0
# 12057                                                NaN    45507.0
# 12058                                                NaN    45514.0
# 12065                    Set up base at the Polar Igloo!    21142.0
# 12071       Battle the hostile mobs in the Nether Fight!    21139.0
# 12078  Drop in for a surprise attack with Aaron’s X-bow!    72005.0
# 12080   Jet off with Macy for a Berserker Bomber battle!    72003.0
# 12082  Wipe out the tech infection with Lance’s Hover...    72001.0
# 12096  Attack the Sons of Garmadon underground dojo i...    70640.0
# 12106  Race against Chopper Maroon for the treasure map!    10755.0
# 12108               Master Spinjitzu with the Red Ninja!    70633.0
# 12111  Create the coolest Spinjitzu tricks with the I...    70636.0
# 12113          Build, rip and spin into action with Nya!    70634.0
# 12115                                                NaN  2000430.0
# 12116                                                NaN  2000431.0
# 12117                                                NaN  2000409.0
# 12118                                                NaN  2000414.0
# 12136              Own a true Sith Lord with Darth Maul!    75537.0
# 12137                 Battle the bad guys with Han Solo!    75535.0
# 12196  Collect the ultimate long-range Rebel starfigh...    75181.0
# 12214  Get ready for high-speed action and impacts wi...    42072.0
# 12235  Bring down Captain Boomerang™ with Batman’s Ba...    70918.0
#
#                                           prod_long_desc review_difficulty  \
# 22     This Gamora LEGO® BrickHeadz construction char...               NaN
# 32     These LEGO® BrickHeadz™ 41610 Tactical Batman™...               NaN
# 48     Pick up your badge and join the LEGO® City Mou...               NaN
# 55     Grab your hard hat and head out to the LEGO® C...               NaN
# 69     Pick up your badge and join the LEGO® City Mou...               NaN
# 84     Be a hero of the LEGO® City Mountain Police Fo...               NaN
# 92     Join the LEGO® City roadwork crew and take car...               NaN
# 94     Pick up your badge and join the LEGO® City Mou...               NaN
# 103    Be part of the action with the LEGO® City poli...               NaN
# 108    Join the LEGO® City coast guard crew and make ...               NaN
# 153    Enjoy racing adventures with the LEGO® Creator...               NaN
# 162    Enjoy a great day at the airshow with this ama...               NaN
# 163    Haul the helicopter to the airfield with the C...              Easy
# 192    Glide over bumps in the Gotham City streets an...               NaN
# 199    These LEGO® BrickHeadz™ 41610 Tactical Batman™...               NaN
# 205    Join in the action-packed LEGO® DC Super Hero ...               NaN
# 208    Join in the action-packed LEGO® DC Super Hero ...               NaN
# 227    Join in the action-packed LEGO® DC Super Hero ...               NaN
# 228    Join in the action-packed LEGO® DC Super Hero ...               NaN
# 231    Enhance you LEGO® DIMENSIONS™ experience with ...               NaN
# 234    Fight crime and battle the forces of evil in t...               NaN
# 261    Join much-loved characters Elsa and Olaf on LE...               NaN
# 267    Join in the Disney•Pixar Cars 3 fun at Guido &...               NaN
# 277    With LEGO® Disney Whisker Haven Tales with the...               NaN
# 278    With LEGO® | Disney Whisker Haven Tales with t...               NaN
# 279    Enter Jurassic World with your child and recre...               NaN
# 280    Little dinosaur fans will love to create endle...               NaN
# 284    Play out real-life scenarios in LEGO® DUPLO® T...               NaN
# 285    Play out real-life scenarios in LEGO® DUPLO® M...               NaN
# 287    Fire your toddler’s imagination with this exci...               NaN
# ...                                                  ...               ...
# 12048  This programmable, intelligent brick serves as...           Average
# 12049  The digital EV3 Gyro Sensor measures the robot...               NaN
# 12050  The digital EV3 Ultrasonic Sensor generates so...       Challenging
# 12051  The digital EV3 Color Sensor distinguishes bet...         Very Easy
# 12052  The digital EV3 Infrared Seeking Sensor detect...               NaN
# 12053  This has been designed for use with the EV3 In...           Average
# 12054  This standard 10V DC transformer allows you to...         Very Easy
# 12055  The EV3 Large Servo Motor is a powerful motor ...               NaN
# 12056  The EV3 Medium Servo Motor is great for lower-...              Easy
# 12057  The analog EV3 Touch Sensor is a simple but ex...               NaN
# 12058  This Cable Pack contains the same seven RJ12 C...               NaN
# 12065  Discover an igloo in a snow-covered biome, com...               NaN
# 12071  Head for the fiery Nether, activate the explod...               NaN
# 12078  Launch an attack on VanByter No. 307 and the C...               NaN
# 12080  Prepare for high-flying action with the Berser...               NaN
# 12082  Help Lance defeat Cezar and CyberByter Dennis ...               NaN
# 12096  Crash into the S.O.G. Headquarters with the Ll...               NaN
# 12106  Get your ninja on and help Zane recover the ma...               NaN
# 12108  Take your Spinjitzu skills to the next level w...               NaN
# 12111  Build, rip and spin into action with the LEGO®...               NaN
# 12113  Be ninja and learn new Spinjitzu tricks with t...               NaN
# 12115  The LEGO® SERIOUS PLAY® program is a radical a...              Easy
# 12116  The LEGO® SERIOUS PLAY® program is a radical a...           Average
# 12117  The LEGO® SERIOUS PLAY® program is a radical a...              Easy
# 12118  The LEGO® SERIOUS PLAY® program is a radical a...              Easy
# 12136  Bolster your LEGO® Star Wars collection with t...               NaN
# 12137  Play out exciting adventures with this highly ...               NaN
# 12196  Own part of Star Wars history with the Y-Wing ...               NaN
# 12214  Experience the amazing power and acceleration ...               NaN
# 12235  Glide over bumps in the Gotham City streets an...               NaN
#
#                                set_name  star_rating              theme_name  \
# 22                               Gamora          5.0              BrickHeadz
# 32         Tactical Batman™ & Superman™          NaN              BrickHeadz
# 48                 Mountain River Heist          NaN                    City
# 55                  Mining Experts Site          5.0                    City
# 69                    Dirt Road Pursuit          NaN                    City
# 84                Mountain Police Chase          NaN                 Juniors
# 92                    Road Repair Truck          NaN                 Juniors
# 94                   Mountain Fugitives          5.0                    City
# 103                Auto Transport Heist          4.0                    City
# 108                     Sailboat Rescue          NaN                    City
# 153                     Extreme Engines          NaN          Creator 3-in-1
# 162                        Airshow Aces          NaN          Creator 3-in-1
# 163                 Chopper Transporter          5.0          Creator 3-in-1
# 192                  The Bat-Dune Buggy          4.5  THE LEGO® BATMAN MOVIE
# 199        Tactical Batman™ & Superman™          NaN              BrickHeadz
# 205                Eclipso™ Dark Palace          NaN     DC Super Hero Girls
# 208    Lena Luthor™ Kryptomite™ Factory          NaN     DC Super Hero Girls
# 227                Eclipso™ Dark Palace          NaN     DC Super Hero Girls
# 228    Lena Luthor™ Kryptomite™ Factory          NaN     DC Super Hero Girls
# 231           Teen Titans Go!™ Fun Pack          NaN             DIMENSIONS™
# 234      The Powerpuff Girls™ Team Pack          NaN             DIMENSIONS™
# 261             Elsa's Market Adventure          NaN                 Disney™
# 267          Guido and Luigi's Pit Stop          5.0                 Juniors
# 277               Petite's Royal Stable          NaN                 Disney™
# 278                     Berry's Kitchen          NaN                 Disney™
# 279                        T. rex Tower          NaN                  DUPLO®
# 280           Gentle Giants Petting Zoo          5.0                  DUPLO®
# 284                     Farm Adventures          NaN                  DUPLO®
# 285                         Town Square          NaN                  DUPLO®
# 287          Large Playground Brick Box          NaN                  DUPLO®
# ...                                 ...          ...                     ...
# 12048             EV3 Intelligent Brick          4.0             MINDSTORMS®
# 12049                   EV3 Gyro Sensor          NaN             MINDSTORMS®
# 12050             EV3 Ultrasonic Sensor          3.5             MINDSTORMS®
# 12051                  EV3 Color Sensor          5.0             MINDSTORMS®
# 12052               EV3 Infrared Sensor          NaN             MINDSTORMS®
# 12053               EV3 Infrared Beacon          5.0             MINDSTORMS®
# 12054                Transformer 10V DC          4.0             MINDSTORMS®
# 12055             EV3 Large Servo Motor          5.0             MINDSTORMS®
# 12056            EV3 Medium Servo Motor          5.0             MINDSTORMS®
# 12057                  EV3 Touch Sensor          NaN             MINDSTORMS®
# 12058                    EV3 Cable Pack          NaN             MINDSTORMS®
# 12065                   The Polar Igloo          NaN              Minecraft™
# 12071                  The Nether Fight          NaN              Minecraft™
# 12078                     Aaron's X-bow          NaN           NEXO KNIGHTS™
# 12080                  Berserker Bomber          NaN           NEXO KNIGHTS™
# 12082             Lance's Hover Jouster          NaN           NEXO KNIGHTS™
# 12096               S.O.G. Headquarters          NaN                NINJAGO®
# 12106         Zane's Ninja Boat Pursuit          NaN                 Juniors
# 12108            Kai - Spinjitzu Master          NaN                NINJAGO®
# 12111           Zane - Spinjitzu Master          NaN                NINJAGO®
# 12113            Nya - Spinjitzu Master          NaN                NINJAGO®
# 12115        Identity and Landscape Kit          4.6           SERIOUS PLAY®
# 12116                   Connections Kit          3.4           SERIOUS PLAY®
# 12117            Window Exploration Bag          5.0           SERIOUS PLAY®
# 12118                       Starter Kit          3.9           SERIOUS PLAY®
# 12136                       Darth Maul™          NaN              Star Wars™
# 12137                         Han Solo™          NaN              Star Wars™
# 12196               Y-Wing Starfighter™          NaN              Star Wars™
# 12214                            WHACK!          5.0                 Technic
# 12235                The Bat-Dune Buggy          4.5  THE LEGO® BATMAN MOVIE
#
#        val_star_rating country
# 22                 NaN      US
# 32                 NaN      US
# 48                 NaN      US
# 55                 5.0      US
# 69                 NaN      US
# 84                 NaN      US
# 92                 NaN      US
# 94                 NaN      US
# 103                3.5      US
# 108                NaN      US
# 153                NaN      US
# 162                NaN      US
# 163                4.5      US
# 192                4.0      US
# 199                NaN      US
# 205                NaN      US
# 208                NaN      US
# 227                NaN      US
# 228                NaN      US
# 231                NaN      US
# 234                NaN      US
# 261                NaN      US
# 267                5.0      US
# 277                NaN      US
# 278                NaN      US
# 279                NaN      US
# 280                NaN      US
# 284                NaN      US
# 285                NaN      US
# 287                NaN      US
# ...                ...     ...
# 12048              3.0      PT
# 12049              NaN      PT
# 12050              4.0      PT
# 12051              5.0      PT
# 12052              NaN      PT
# 12053              3.3      PT
# 12054              2.5      PT
# 12055              5.0      PT
# 12056              NaN      PT
# 12057              NaN      PT
# 12058              NaN      PT
# 12065              NaN      PT
# 12071              NaN      PT
# 12078              NaN      PT
# 12080              NaN      PT
# 12082              NaN      PT
# 12096              NaN      PT
# 12106              NaN      PT
# 12108              NaN      PT
# 12111              NaN      PT
# 12113              NaN      PT
# 12115              3.6      PT
# 12116              2.9      PT
# 12117              5.0      PT
# 12118              3.3      PT
# 12136              NaN      PT
# 12137              NaN      PT
# 12196              NaN      PT
# 12214              5.0      PT
# 12235              4.0      PT
#
# [2351 rows x 14 columns]

# %% [markdown]
# #### Interpreting the Results
#
# Read the output above, and then answer the following questions:
#
# How many total rows are in this DataFrame?  How many columns contain numeric data? How many contain categorical data?  Identify at least 3 columns that contain missing values.
#
# Write your answer below this line:
# ________________________________________________________________________________________________________________________________
#
# rows = 12261
# numeric cols = 7
# categorical = 7

# %% [markdown]
# Answer question here...

# %% [markdown]
# ## Using `.describe()`
#
# Whereas `.info()` provides statistics about the DataFrame itself, `.describe()` returns output containing basic summary statistics about the data contained with the DataFrame.
#
# In the cell below, call the DataFrame's `.describe()` method.

# %% [markdown]
# #### Interpreting the Results
#
# The output contains descriptive statistics corresponding to the columns.  Use these to answer the following questions:
#
# How much is the standard deviation for piece count?  How many pieces are in the largest lego set?  How many in the smallest lego set? What is the median `val_star_rating`?
#
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# Answer questions here...

# %% [markdown]
# ## Getting Summary Statistics
#
# Pandas also allows us to easily compute individual summary statistics using built-in methods.  Next, we'll get some practice using these methods.
#
# In the cell below, compute the median value of the `star_rating` column.

# %% [markdown]
# Next, get a count of the total number of values in `play_star_rating`.

# %% [markdown]
# Now, compute the standard deviation of the `list_price` column.

# %% [markdown]
# If we bought every single lego set in this dataset, how many pieces would we have?  Use the `.sum()` method on the correct column to compute this.

# %% [markdown]
# Now, let's try getting the value for the 90% quantile.  Do this in the cell below.

# %% [markdown]
# ## Getting Summary Statistics on Categorical Data
#
# For obvious reasons, most of the methods we've used so far only work with numerical data--there's no way to calculate the standard deviation of a column containing string values. However, there are some things that we can discover about columns containing categorical data.
#
# In the cell below, get the `.unique()` values contained within the `review_difficulty` column.

# %% [markdown]
# Now, let's get the `value_counts` for this column, to see how common each is.

# %% [markdown]
# As you can see, these provide us quick and easy ways to get information on columns containing categorical information.
#
#
# ## Using `.applymap()`
#
# When working with pandas DataFrames, we can quickly compute functions on the data contained by using the `applymap()` function and passing in a lambda function.
#
# For instance, we can use `applymap()` to return a version of the DataFrame where every value has been converted to a string.
#
# In the cell below:
#
# * Call our DataFrame's `.applymap()` function and pass in `lambda x: str(x)`
# * Call our new `string_df` object's `.info()` method to confirm that everything has been cast to a string

# %%
string_df = None

# %% [markdown]
# Note that everything--even the `NaN` values, have been cast to a string in the example above.
#
# Note that for pandas Series objects (such as a single column in a DataFrame), we can do the same thing using the `apply()` method.
#
# This is just one example of how we can quickly compute custom functions on our DataFrame--this will become especially useful when we learn how to **_normalize_** our datasets in a later section!
#
# # Conclusion
#
# In this lab, we learned how to:
#
# * Understand and use the df.describe() and df.info() summary statistics methods
# * Use built-in Pandas methods for calculating summary statistics (.mean(), .std(), .count(), .sum(), .mean(), .median(), .std(), .var() and .quantile())
# * Apply a function to every element in a Series or DataFrame using s.apply() and df.applymap()
